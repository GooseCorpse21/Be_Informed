# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sqlalchemy as sq

# %% [markdown]
# Branded food

# %%
food = pd.read_csv('../data/branded_food.csv', low_memory = False)
pd.set_option('display.max_columns', None)
food.columns = [column.replace(" ", "_") for column in food.columns]

# %% [markdown]
# Recalls 2017-2025

# %%
recalls_df = pd.read_excel('../data/FDA Recall.xlsx')
recalls_df.columns = [column.replace("-", "_") for column in recalls_df.columns]

# %%
recalls_df
# Out:
#            Date                                Brand_Names  \
# 0    2022-09-29                               The Chai Box
# 1    2022-09-29  Golden State Medical Supply, Incorporated
# 2    2022-09-30                               Zerto Fontal
# 3    2022-10-04                                Saint Louis
# 4    2022-10-05                                   Multiple
# ...         ...                                        ...
# 1196 2024-02-27                             Avanos Medical
# 1197 2024-12-10                     Sprouts Farmers Market
# 1198 2024-12-10                                    Borsari
# 1199 2024-12-10                                   MadeGood
# 1200 2024-12-12                              Daily Veggies
#
#                                     Product_Description  \
# 0     CHAI CONCENTRATE MIX  AND  CHAI CONCENTRATE UN...
# 1       Clopidogrel 75mg Tablets, Atenolol 25mg Tablets
# 2                                “Zerto Fontal”, Cheese
# ...

# %% [markdown]
# - Q1

# %%
food_bev = recalls_df.loc[recalls_df['Product_Types'] == 'Food & Beverages']

# %%
food_bev
# Out:
#            Date             Brand_Names  \
# 0    2022-09-29            The Chai Box
# 2    2022-09-30            Zerto Fontal
# 8    2022-10-11                 JLM TUB
# 12   2022-10-17     NESTLÉ® TOLL HOUSE®
# 13   2022-10-17               Hammond’s
# ...         ...                     ...
# 1182 2024-06-28         Diamond Shruumz
# 1187 2024-12-06         F&S Fresh Foods
# 1188 2024-12-06    Fresh Creative Foods
# 1192 2024-12-07  Dairyland Produce, LLC
# 1199 2024-12-10                MadeGood
#
#                                     Product_Description     Product_Types  \
# 0     CHAI CONCENTRATE MIX  AND  CHAI CONCENTRATE UN...  Food & Beverages
# 2                                “Zerto Fontal”, Cheese  Food & Beverages
# 8     Sesame sticks mix and roasted and salted sunfl...  Food & Beverages
# 12    STUFFED Chocolate Chip Cookie Dough with Fudge...  Food & Beverages
# 13                               Salted Caramel Cookies  Food & Beverages
# ...

# %%
salmonella = food_bev['Recall_Reason_Description'].str.contains('Salmonella', na=False)
food_bev.loc[salmonella]
# Out:
#            Date                                        Brand_Names  \
# 32   2022-11-07                                             Gamesa
# 54   2022-04-28                                              Elite
# 69   2022-05-20                                               Jif®
# 74   2022-05-21                                               Wawa
# 75   2022-05-24                                      Fresh Seasons
# 76   2022-05-24                               Multiple brand names
# 80   2022-05-25                               Multiple brand names
# 90   2022-05-28                                        Giant Eagle
# 91   2022-05-28                                         Quick Chek
# 188  2022-08-23                                      Mighty Sesame
# 193  2022-08-30                                 Three Golden Coins
# 251  2022-12-23                                    Wegmans Organic
# 326  2021-08-16                                            Hostess
# ...

# %%
shiga = food_bev['Recall_Reason_Description'].str.contains('Shiga toxin', na=False)
food_bev.loc[shiga]
# Out:
#            Date           Brand_Names  \
# 1138 2024-11-20              Fabalish
# 1156 2024-11-21    Whole Foods Market
# 1157 2024-11-22  Multiple brand names
# 1172 2024-11-16  Multiple Brand Names
#
#                                  Product_Description     Product_Types  \
# 1138                   “Kickin” Carrot Falafel Bites  Food & Beverages
# 1156                        Organic Carrots & Celery  Food & Beverages
# 1157                           Organic whole carrots  Food & Beverages
# 1172  Organic whole carrots and organic baby carrots  Food & Beverages
#
#                               Recall_Reason_Description     Company_Name  \
# 1138  Potential Shiga toxin-producing Escherichia co...    Fabalish Inc.
# 1156  Potential Foodborne Illness - Shiga toxin-prod...  F&S Fresh Foods
# 1157  Potential Foodborne Illness - Shiga toxin-prod...   Grimmway Farms
# 1172  Products may be contaminated with Shiga toxin-...   Grimmway Farms
#
#      Terminated Recall
# ...

# %%
cronobacter = food_bev['Recall_Reason_Description'].str.contains('Crono', na=False)
food_bev.loc[cronobacter]
# Out:
#           Date        Brand_Names  \
# 142 2023-03-17  Gerber Good Start
# 227 2023-05-14  Gerber Good Start
# 628 2022-08-13    King’s Hawaiian
# 812 2022-12-11            ByHeart
#
#                                    Product_Description     Product_Types  \
# 142                            Powdered Infant formula  Food & Beverages
# 227                            Powdered Infant Formula  Food & Beverages
# 628  Pretzel Slider Buns, Pretzel Hamburger Buns an...  Food & Beverages
# 812  Whole Nutrition Infant Formula, Milk Based Pow...  Food & Beverages
#
#                              Recall_Reason_Description  \
# 142      Potential Cronobacter sakazakii contamination
# 227      Potential Cronobacter sakazakii contamination
# 628  Due to the potential for microbial contaminati...
# 812  Potential for cross-contamination with Cronoba...
#
#                            Company_Name Terminated Recall
# 142                 Perrigo Company plc               NaN
# ...

# %%
clostridium = food_bev['Recall_Reason_Description'].str.contains('Clostr', na=False)
food_bev.loc[clostridium]
# Out:
#            Date      Brand_Names  \
# 0    2022-09-29     The Chai Box
# 628  2022-08-13  King’s Hawaiian
# 1079 2024-03-06         AJI MORI
#
#                                     Product_Description     Product_Types  \
# 0     CHAI CONCENTRATE MIX  AND  CHAI CONCENTRATE UN...  Food & Beverages
# 628   Pretzel Slider Buns, Pretzel Hamburger Buns an...  Food & Beverages
# 1079                                   CHILLIMAMI SAUCE  Food & Beverages
#
#                               Recall_Reason_Description  \
# 0     Potential under-processing which may lead to C...
# 628   Due to the potential for microbial contaminati...
# 1079  Potential Foodborne Illness - Clostridium botu...
#
#                            Company_Name Terminated Recall
# 0                          The Chai Box        Terminated
# 628                     King’s Hawaiian        Terminated
# 1079  AJI MORI Sauce Corp. DBA Susi Koo        Terminated

# %%
ecoli = food_bev['Recall_Reason_Description'].str.contains('E. Coli', na=False)
food_bev.loc[ecoli]
# Out:
#           Date   Brand_Names                   Product_Description  \
# 101 2022-06-14         Built  Protein Bar – Banana Cream Pie Puffs
# 465 2019-11-27  Hodgson Mill                      Unbleached Flour
# 976 2024-02-17  Raw Farm LLC                    Raw Cheddar Cheese
#
#         Product_Types                     Recall_Reason_Description  \
# 101  Food & Beverages                  Potential Pathogenic E. Coli
# 465  Food & Beverages               Potential E. Coli Contamination
# 976  Food & Beverages  Potential contamination with E. Coli 0157:H7
#
#            Company_Name Terminated Recall
# 101   Built Brands, LLC        Terminated
# 465  Hodgson Mill, Inc.        Terminated
# 976        Raw Farm LLC               NaN

# %%
listeria = food_bev['Recall_Reason_Description'].str.contains('Listeria', na=False)
food_bev.loc[listeria]
# Out:
#            Date                    Brand_Names  \
# 33   2022-11-08                          Giant
# 37   2022-11-17              Green Day Produce
# 48   2022-04-21             Whole Foods Market
# 96   2022-06-03              Irvington Seafood
# 109  2022-06-30                    Little Bear
# ...         ...                            ...
# 1125 2024-10-19          Multiple Store Brands
# 1127 2024-10-23           Multiple brand names
# 1132 2024-11-05  Aldi, La Bonne Vie and others
# 1151 2022-09-30                       Multiple
# 1161 2024-11-08              CF, J&O and other
#
#                                     Product_Description     Product_Types  \
# 33                                        Smoked Salmon  Food & Beverages
# 37                                      Enoki Mushrooms  Food & Beverages
# 48    Red Lentil Dal, which includes Pickled Curry C...  Food & Beverages
# 96         Crabmeat: Jumbo, Lump, Finger, and Claw meat  Food & Beverages
# ...

# %%
hep_a = food_bev['Recall_Reason_Description'].str.contains('Hep', na=False)
food_bev.loc[hep_a]
# Out:
#            Date          Brand_Names  \
# 140  2023-03-16   Kirkland Signature
# 1006 2023-06-09  Wawona Frozen Foods
#
#                                   Product_Description     Product_Types  \
# 140                       Frozen Organic Strawberries  Food & Beverages
# 1006  Organic Daybreak Blend 4lb bags of frozen fruit  Food & Beverages
#
#                           Recall_Reason_Description  \
# 140                                     Hepatitis A
# 1006  Potential to be contaminated with Hepatitis A
#
#                    Company_Name Terminated Recall
# 140   California Splendor, Inc.        Terminated
# 1006  Wawona Frozen Foods, Inc.               NaN

# %%
ochra = food_bev['Recall_Reason_Description'].str.contains('Ochra', na=False)
food_bev.loc[ochra]
# Out:
#           Date   Brand_Names         Product_Description     Product_Types  \
# 247 2022-12-15  World Market  Pepper Collection Gift Set  Food & Beverages
#
#                              Recall_Reason_Description  \
# 247  Mold (Aspergillus brasiliensis) and Ochratoxin...
#
#                     Company_Name Terminated Recall
# 247  Something South African LLC        Terminated

# %%
fungi = food_bev['Recall_Reason_Description'].str.contains('Aspergill', na=False)
food_bev.loc[fungi]
# Out:
#           Date   Brand_Names         Product_Description     Product_Types  \
# 247 2022-12-15  World Market  Pepper Collection Gift Set  Food & Beverages
#
#                              Recall_Reason_Description  \
# 247  Mold (Aspergillus brasiliensis) and Ochratoxin...
#
#                     Company_Name Terminated Recall
# 247  Something South African LLC        Terminated

# %%
tala_mold = food_bev['Recall_Reason_Description'].str.contains('Mold', na=False)
food_bev.loc[tala_mold]
# Out:
#           Date   Brand_Names         Product_Description     Product_Types  \
# 247 2022-12-15  World Market  Pepper Collection Gift Set  Food & Beverages
#
#                              Recall_Reason_Description  \
# 247  Mold (Aspergillus brasiliensis) and Ochratoxin...
#
#                     Company_Name Terminated Recall
# 247  Something South African LLC        Terminated

# %% [markdown]
#     FUNGI, MOLD, BACTERIA, ETC.
# ochra, salmonella, fungi, tala_mold, hep_a, listeria, clostridium, cronobacter, ecoli, shiga

# %% [markdown]
# - Q2

# %%
pet_food =  recalls_df.loc[recalls_df['Product_Types'].str.contains('Pet Food', na=False)]
pet_food
# Out:
#            Date                                Brand_Names  \
# 40   2022-12-02                                     Purina
# 113  2022-07-06                      Primal Pet Foods Inc.
# 143  2023-03-20                                     Kaytee
# 279  2021-10-12                               Nutri Source
# 309  2021-03-03                        Bravo Packing, Inc.
# 313  2021-03-27                            Multiple brands
# 321  2021-10-01               Fromm Four-Star Nutritionals
# 325  2021-08-13                             Simply Nourish
# 414  2022-01-04                                 Pure Being
# 463  2019-11-18                                      Quest
# 567  2023-10-21                                  Retriever
# 635  2023-09-04                                     Victor
# 868  2024-06-22                         Sunseed Vita Prima
# 935  2019-01-31                        Hill's Science Diet
# 962  2019-08-15                                Texas Tripe
# ...

# %%
pet_food['Recall_Reason_Description'].max()
# Out:
# 'Salmonella contamination'

# %% [markdown]
# - Q3

# %%
nuts = food_bev.loc[food_bev['Brand_Names'].str.contains('Slim Jim', na=False)]

# %% [markdown]
# - Q4

# %%
animals = recalls_df.loc[recalls_df['Product_Types'].str.contains('Livestock', na=False)]

# %%
animals

# %% [markdown]
# - Q5

# %%
poison = food_bev.loc[food_bev['Recall_Reason_Description'].str.contains('yellow ole', na=False)]

# %%
poison
# Out:
#            Date          Brand_Names  \
# 781  2024-02-23            H&Natural
# 782  2024-02-23        Alipotec King
# 844  2024-04-04  Green ELV Nutrition
# 1075 2024-01-12         ELV Alipotec
#
#                                     Product_Description     Product_Types  \
# 781   Brazil Seed Pure Natural Semilla de Brasil & T...  Food & Beverages
# 782                           Alipotec Raiz de Tejocote  Food & Beverages
# 844                       Elv Control Herbal Supplement  Food & Beverages
# 1075                    Mexican Tejocte Root Supplement  Food & Beverages
#
#                               Recall_Reason_Description  \
# 781   Product contains yellow oleander, a poisonous ...
# 782   Product contains yellow oleander, a poisonous ...
# 844                   Product contains yellow oleander.
# 1075                  Product contains yellow oleander.
#
#                      Company_Name Terminated Recall
# 781       G.A. Mart dba H&Natural               NaN
# ...

# %% [markdown]
# New Data

# %%
cause_effect = pd.read_csv('../data/cause_effect.csv')

# %%
illness = pd.read_csv('../data/f_illness_report.csv')

# %%
poor = pd.read_csv('../data/School_Neighborhood_Poverty_Estimates,_2020-21.csv')

# %%
cause_effect
# Out:
#        Pathogen                         table_id Food_category  Year  \
# 0    Salmonella           Beef_Newport_2011-2015          Beef  2020
# 1    Salmonella           Beef_Newport_2016-2020          Beef  2020
# 2    Salmonella       Beef_Typhimurium_2011-2015          Beef  2020
# 3    Salmonella       Beef_Typhimurium_2016-2020          Beef  2020
# 4    Salmonella            Beef_Dublin_2011-2015          Beef  2020
# ..          ...                              ...           ...   ...
# 479  Salmonella         Turkey_Newport_2019-2023        Turkey  2023
# 480  Salmonella         Turkey_Reading_2014-2018        Turkey  2023
# 481  Salmonella         Turkey_Reading_2019-2023        Turkey  2023
# 482  Salmonella  Turkey_Schwarzengrund_2014-2018        Turkey  2023
# 483  Salmonella  Turkey_Schwarzengrund_2019-2023        Turkey  2023
#
#            Serotype                 Burden Trajectory Year_range  \
# 0           Newport                   High  Increased  2011-2015
# ...

# %%
illness
# Out:
#         Year  Month State Source       Pathogen  Serotype/Species  \
# 0       2025      1    AL  Stool  Campylobacter            jejuni
# 1       2025      1    AR  Stool  Campylobacter            jejuni
# 2       2025      1    CT  Blood  Campylobacter              coli
# 3       2025      1    CT  Stool  Campylobacter            jejuni
# 4       2025      1    DC  Stool  Campylobacter            jejuni
# ...      ...    ...   ...    ...            ...               ...
# 158451  2018     12    WV  Stool       Shigella   Shigella sonnei
# 158452  2018     12    CA  Other         Vibrio  parahaemolyticus
# 158453  2018     12    ND  Stool         Vibrio  parahaemolyticus
# 158454  2018     12    NY  Stool         Vibrio  parahaemolyticus
# 158455  2018     12    TX  Other         Vibrio  parahaemolyticus
#
#         Number of isolates  Outbreak associated isolates  \
# 0                        1                           NaN
# ...
